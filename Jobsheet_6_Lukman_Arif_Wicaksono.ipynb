# %% [markdown]
# <a href="https://colab.research.google.com/github/KyroooKay/Pemrograman_Berorientasi_Object/blob/Jobsheet-6/Jobsheet_6_Lukman_Arif_Wicaksono.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 6.1

# %%
# Impor komponen yang diperlukan dari modul abc
from abc import ABC, abstractmethod

# 1. Definisikan Kelas Abstrak
class KendaraanAbstrak(ABC):
    def __init__(self, merk):
        self.merk = merk
        print(f"Inisialisasi KendaraanAbstrak dengan merk: {self.merk}")

    # Metode konkret (tidak abstrak)
    def info_merk(self):
        print(f"Merk kendaraan ini adalah {self.merk}.")

    # 2. Definisikan Metode Abstrak
    @abstractmethod
    def start_mesin(self):
        print(f"Mesin mobil {self.merk} dinyalakan.")

    @abstractmethod
    def stop_mesin(self):
        print(f"Mesin mobil {self.merk} dimatikan.")

# --- Kode Utama ---
if __name__ == "__main__":
    print("Definisi Kelas Abstrak 'KendaraanAbstrak' selesai.")

    # Contoh definisi kelas anak (konkret)
    class Mobil(KendaraanAbstrak):
        # Implementasi metode abstrak start_mesin
        def start_mesin(self):
            print(f"Mesin mobil {self.merk} dinyalakan.")

        # Implementasi metode abstrak stop_mesin
        def stop_mesin(self):
            print(f"Mesin mobil {self.merk} dimatikan.")

    print("\nContoh definisi kelas anak 'Mobil' selesai.")

    # Membuat objek dari kelas anak (konkret) diperbolehkan
    mobil_contoh = Mobil("Toyota")

    # Memanggil metode
    mobil_contoh.start_mesin()
    mobil_contoh.info_merk()
    mobil_contoh.stop_mesin()
# Out:
# Definisi Kelas Abstrak 'KendaraanAbstrak' selesai.
#
# Contoh definisi kelas anak 'Mobil' selesai.
# Inisialisasi KendaraanAbstrak dengan merk: Toyota
# Mesin mobil Toyota dinyalakan.
# Merk kendaraan ini adalah Toyota.
# Mesin mobil Toyota dimatikan.

# %% [markdown]
# Praktikum 6.2

# %%
from abc import ABC, abstractmethod

# Definisikan kelas abstrak
class MediaAbstrak(ABC):
    def __init__(self, judul):
        self.judul = judul
        print(f"Inisialisasi MediaAbstrak dengan judul: {self.judul}")

    @abstractmethod
    def play(self):
        """Metode abstrak untuk memulai pemutaran."""
        pass

    @abstractmethod
    def stop(self):
        """Metode abstrak untuk menghentikan pemutaran."""
        pass

# --- Kode Utama ---
if __name__ == "__main__":
    print("Mencoba membuat objek dari kelas abstrak MediaAbstrak...")

    try:
        # Baris ini akan menyebabkan TypeError
        media = MediaAbstrak("Konten Abstrak")
        print("Objek berhasil dibuat (SEHARUSNYA TIDAK TERJADI).")
        media.play()
    except TypeError as e:
        print(f"\nGAGAL membuat objek!")
        print(f"Error yang muncul (sesuai harapan): {e}")
        print("\nIni membuktikan bahwa kelas abstrak tidak bisa diinstansiasi")
        print("jika masih memiliki metode abstrak yang belum diimplementasikan.")
# Out:
# Mencoba membuat objek dari kelas abstrak MediaAbstrak...
#
# GAGAL membuat objek!
# Error yang muncul (sesuai harapan): Can't instantiate abstract class MediaAbstrak without an implementation for abstract methods 'play', 'stop'
#
# Ini membuktikan bahwa kelas abstrak tidak bisa diinstansiasi
# jika masih memiliki metode abstrak yang belum diimplementasikan.

# %% [markdown]
# Praktikum 6.3

# %%
from abc import ABC, abstractmethod
import locale
import random

try:
    locale.setlocale(locale.LC_ALL, 'id_ID.UTF-8')
except locale.Error:
    print("Locale id_ID.UTF-8 tidak tersedia, gunakan locale default.")

def format_rupiah(angka):
    return locale.currency(angka, grouping=True, symbol='Rp ')

# Kelas Abstrak
class AlatPembayaranAbstrak(ABC):
    def __init__(self, nama_metode):
        self.nama_metode = nama_metode
        print(f"Inisialisasi alat pembayaran: {self.nama_metode}")

    def info(self):
        print(f"Metode Pembayaran: {self.nama_metode}")

    @abstractmethod
    def proses_pembayaran(self, jumlah):
        pass

# 1. Subclass Konkret Pertama: KartuKredit
class KartuKredit(AlatPembayaranAbstrak):
    def __init__(self, nomor_kartu, nama_pemilik):
        super().__init__("Kartu Kredit")
        self.nomor_kartu = nomor_kartu
        self.nama_pemilik = nama_pemilik
        print(f" -> Kartu Kredit {self.nomor_kartu} atas nama {self.nama_pemilik} siap.")

    def proses_pembayaran(self, jumlah):
        print(f" Memproses pembayaran {format_rupiah(jumlah)} via Kartu Kredit {self.nomor_kartu}...")
        print(" Pembayaran Kartu Kredit Berhasil.")
        return True

# 2. Subclass Konkret Kedua: DompetDigital
class DompetDigital(AlatPembayaranAbstrak):
    def __init__(self, nomor_telepon, nama_provider):
        super().__init__(f"Dompet Digital ({nama_provider})")
        self.nomor_telepon = nomor_telepon
        self._saldo = random.randint(50000, 500000)
        print(f" -> Dompet Digital {self.nomor_telepon} siap (Saldo: {format_rupiah(self._saldo)}).")

    def proses_pembayaran(self, jumlah):
        print(f" Memproses pembayaran {format_rupiah(jumlah)} via Dompet Digital {self.nomor_telepon}...")
        if jumlah <= self._saldo:
            self._saldo -= jumlah
            print(" Pembayaran Dompet Digital Berhasil.")
            print(f" Saldo tersisa: {format_rupiah(self._saldo)}")
            return True
        else:
            print(" Pembayaran Dompet Digital Gagal (Saldo tidak mencukupi).")
            print(f" Saldo saat ini: {format_rupiah(self._saldo)}")
            return False

# --- Kode Utama ---
if __name__ == "__main__":
    print("\nMembuat Objek Alat Pembayaran...")
    kartu_bca = KartuKredit("1234-5678-9012-3456", "Budi Cahyono")
    gopay = DompetDigital("08123456789", "GoPay")

    print("\nMelakukan Pembayaran:")

    print("\nMencoba bayar dengan Kartu Kredit:")
    kartu_bca.info()
    status_kk = kartu_bca.proses_pembayaran(150000)
    print(f" Status Transaksi KK: {'Sukses' if status_kk else 'Gagal'}")

    print("\nMencoba bayar dengan GoPay (Jumlah Kecil):")
    gopay.info()
    status_gopay1 = gopay.proses_pembayaran(75000)
    print(f" Status Transaksi GoPay 1: {'Sukses' if status_gopay1 else 'Gagal'}")

    print("\nMencoba bayar dengan GoPay (Jumlah Besar):")
    gopay.info()
    status_gopay2 = gopay.proses_pembayaran(1000000)
    print(f" Status Transaksi GoPay 2: {'Sukses' if status_gopay2 else 'Gagal'}")

# %% [markdown]
# 6.4

# %%
from abc import ABC, abstractmethod
import time

class DokumenAbstrak(ABC):
    def __init__(self, nama_file):
        self.nama_file = nama_file
        print(f"Inisialisasi Dokumen: {self.nama_file}")

    def info_file(self):
        print(f"Nama File: {self.nama_file}")

    @abstractmethod
    def cetak(self): pass

    @abstractmethod
    def simpan(self): pass

class DokumenTeks(DokumenAbstrak):
    def __init__(self, nama_file, isi_teks):
        super().__init__(nama_file)
        self.isi_teks = isi_teks
        print(" -> Tipe: Dokumen Teks")

    def cetak(self):
        print(f"Mencetak Dokumen Teks '{self.nama_file}':")
        print("="*15)
        print(self.isi_teks)
        print("="*15)

    def simpan(self):
        print(f"Menyimpan Dokumen Teks '{self.nama_file}' ke disk...")
        time.sleep(0.2)
        print(" -> Berhasil disimpan.")

class Spreadsheet(DokumenAbstrak):
    def __init__(self, nama_file, baris, kolom):
        super().__init__(nama_file)
        self.baris = baris
        self.kolom = kolom
        print(" -> Tipe: Spreadsheet")

    def cetak(self):
        print(f"Mencetak Spreadsheet '{self.nama_file}' ({self.baris}x{self.kolom}):")
        print("[Tabel Data Disini]")

    def simpan(self):
        print(f"Menyimpan Spreadsheet '{self.nama_file}' ke disk...")
        time.sleep(0.2)
        print(" -> Berhasil disimpan.")

def proses_dokumen(list_dokumen):
    print("\n======= MEMPROSES DOKUMEN =======")
    for doc in list_dokumen:
        try:
            print(f"\nMemproses: {doc.nama_file}")
            doc.info_file()
            doc.cetak()
            doc.simpan()
        except Exception as e:
            print(f" Error saat memproses {doc.nama_file}: {e}")
    print("\n======= SELESAI MEMPROSES DOKUMEN =======")

if __name__ == "__main__":
    print("Membuat Dokumen...")
    dok1 = DokumenTeks("laporan.txt", "Ini adalah isi laporan singkat.")
    dok2 = Spreadsheet("data_penjualan.xlsx", 200, 15)
    dok3 = DokumenTeks("catatan_rapat.txt", "Poin penting:\n- Bahas budget\n- Tentukan timeline")

    koleksi_dokumen = [dok1, dok2, dok3]
    proses_dokumen(koleksi_dokumen)

# %% [markdown]
# 6.5

# %%
from abc import ABC, abstractmethod
import math

class BangunDatarAbstrak(ABC):
    def __init__(self, nama):
        self._nama = nama
        print(f"Inisialisasi BangunDatarAbstrak: {self._nama}")

    @property
    def nama(self): return self._nama

    def info_lengkap(self):
        print(f"\n--- Info Lengkap: {self.nama} ---")
        try:
            print(f" Luas : {self.hitung_luas():.2f}")
        except NotImplementedError:
            print(" Luas : Belum diimplementasikan.")

        try:
            print(f" Keliling : {self.hitung_keliling():.2f}")
        except NotImplementedError:
            print(" Keliling : Belum diimplementasikan.")
        print("-" * (len(self.nama) + 18))

    @abstractmethod
    def hitung_luas(self): pass

    @abstractmethod
    def hitung_keliling(self): pass

class Lingkaran(BangunDatarAbstrak):
    def __init__(self, radius):
        super().__init__("Lingkaran")
        if radius < 0:
            raise ValueError("Radius tidak boleh negatif")
        self.radius = radius
        print(f" -> Lingkaran dengan radius: {self.radius}")

    def hitung_luas(self): return math.pi * (self.radius ** 2)
    def hitung_keliling(self): return 2 * math.pi * self.radius

if __name__ == "__main__":
    print("Membuat Objek Lingkaran...")
    lingkaran_A = Lingkaran(5)
    lingkaran_A.info_lengkap()

# %% [markdown]
# Praktikum 6.6

# %%
from abc import ABC, abstractmethod

# 1. Kelas Abstrak Induk (Senjata)
class Senjata(ABC):
    def __init__(self, nama):
        self.nama = nama

    def info_nama(self):
        print(f"Senjata: {self.nama}")

    @abstractmethod
    def serang(self):
        """Metode abstrak untuk menyerang"""
        pass

    @property
    @abstractmethod
    def amunisi(self):
        """Properti abstrak untuk mengambil info amunisi / daya tahan"""
        pass

# 2. Kelas Anak Konkret 1 (Pedang)
class Pedang(Senjata):
    def __init__(self, nama, panjang_bilah):
        super().__init__(nama)
        self.panjang_bilah = panjang_bilah
        self._daya_tahan = 100 # Daya tahan penuh 100

    def serang(self):
        if self._daya_tahan > 0:
            self._daya_tahan -= 10
            print(f"Pedang {self.nama} menebas dengan bilah sepanjang {self.panjang_bilah} cm!")
        else:
            print(f"Pedang {self.nama} tumpul dan rusak!")

    @property
    def amunisi(self):
        return f"{self._daya_tahan}%"

# 3. Kelas Anak Konkret 2 (Panah)
class Panah(Senjata):
    def __init__(self, nama, jumlah_anak_panah):
        super().__init__(nama)
        self._jumlah_anak_panah = jumlah_anak_panah

    def serang(self):
        if self._jumlah_anak_panah > 0:
            self._jumlah_anak_panah -= 1
            print(f"Panah {self.nama} melesat! Sisa anak panah: {self._jumlah_anak_panah}")
        else:
            print(f"Amunisi Panah {self.nama} habis!")

    @property
    def amunisi(self):
        return f"{self._jumlah_anak_panah} anak panah"

# 4. Kode Utama
if __name__ == "__main__":
    print("--- Demonstrasi Senjata ---")

    # Objek Pedang
    excalibur = Pedang("Excalibur", 120.5)
    excalibur.info_nama()
    excalibur.serang()
    excalibur.serang()
    print(f"Sisa Daya Tahan: {excalibur.amunisi}\n")

    # Objek Panah
    busur_elf = Panah("Busur Elf", 2)
    busur_elf.info_nama()
    busur_elf.serang()
    busur_elf.serang()
    busur_elf.serang() # Seharusnya menampilkan pesan habis
    print(f"Sisa Amunisi: {busur_elf.amunisi}")

# %% [markdown]
# Penugasan

# %%
from abc import ABC, abstractmethod

class Senjata(ABC):
    def __init__(self, nama):
        self.nama = nama

    def info_nama(self):
        print(f"Senjata: {self.nama}")

    @abstractmethod
    def serang(self):
        pass

    @property
    @abstractmethod
    def amunisi(self):
        pass

class HeavenlyScythe(Senjata):
    def __init__(self, nama, panjang_gagang):
        super().__init__(nama)
        self.panjang_gagang = panjang_gagang
        self._daya_tahan = 100

    def serang(self):
        if self._daya_tahan > 0:
            self._daya_tahan -= 15
            print(f"{self.nama} mengayun tajam dengan jangkauan {self.panjang_gagang} cm!")
        else:
            print(f"{self.nama} tumpul dan butuh perbaikan!")

    @property
    def amunisi(self):
        return f"{self._daya_tahan}%"

class BowOfDestruction(Senjata):
    def __init__(self, nama, jumlah_anak_panah):
        super().__init__(nama)
        self._jumlah_anak_panah = jumlah_anak_panah

    def serang(self):
        if self._jumlah_anak_panah > 0:
            self._jumlah_anak_panah -= 1
            print(f"{self.nama} menembakkan panah mematikan! Sisa: {self._jumlah_anak_panah}")
        else:
            print(f"Amunisi {self.nama} telah habis!")

    @property
    def amunisi(self):
        return f"{self._jumlah_anak_panah} anak panah"

if __name__ == "__main__":
    scythe = HeavenlyScythe("Heavenly Scythe", 180.5)
    scythe.info_nama()
    scythe.serang()
    scythe.serang()
    print(f"Sisa Daya Tahan: {scythe.amunisi}\n")

    bow = BowOfDestruction("Bow of Destruction", 2)
    bow.info_nama()
    bow.serang()
    bow.serang()
    bow.serang()
    print(f"Sisa Amunisi: {bow.amunisi}")
# Out:
# Senjata: Heavenly Scythe
# Heavenly Scythe mengayun tajam dengan jangkauan 180.5 cm!
# Heavenly Scythe mengayun tajam dengan jangkauan 180.5 cm!
# Sisa Daya Tahan: 70%
#
# Senjata: Bow of Destruction
# Bow of Destruction menembakkan panah mematikan! Sisa: 1
# Bow of Destruction menembakkan panah mematikan! Sisa: 0
# Amunisi Bow of Destruction telah habis!
# Sisa Amunisi: 0 anak panah
