# %% [markdown]
# <a href="https://colab.research.google.com/github/KyroooKay/Pemrograman_Berorientasi_Object/blob/Jobsheet-12/JOBSHEET_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Praktikum 1: Persiapan Data (CSV)

# %%
# %%writefile lokasi_semarang.csv
# Nama,Latitude,Longitude,Tipe,Deskripsi
# Lawang Sewu,-6.9840,110.4105,Wisata Sejarah,Bangunan bersejarah peninggalan Belanda dengan banyak pintu.
# Simpang Lima,-6.9929,110.4200,Landmark,"Alun-alun pusat kota Semarang, tempat berkumpul populer."
# Masjid Agung Jawa Tengah,-6.9892,110.4452,Tempat Ibadah,Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.
# Klenteng Sam Poo Kong,-6.9980,110.4030,Tempat Ibadah,Klenteng bersejarah peninggalan Laksamana Cheng Ho.
# Brown Canyon,-7.0375,110.4875,Wisata Alam,"Tebing bekas penambangan galian C yang unik menyerupai Grand Canyon."
# Lumpia Gang Lombok,-6.9718,110.4255,Kuliner,Salah satu tempat makan lumpia legendaris dan otentik di Semarang.
# Kota Lama,-6.9690,110.4250,Wisata Sejarah,"Kawasan cagar budaya dengan bangunan-bangunan kuno bergaya Eropa."
# Pantai Marina,-6.9585,110.3875,Wisata Alam,Kawasan pantai rekreasi di bagian utara kota.
# Kampoeng Kopi Banaran,-7.2780,110.4010,Wisata Alam,"Agrowisata kebun kopi dengan pemandangan dan restoran."
# Toko Oen,-6.9715,110.4235,Kuliner,Restoran dan toko es krim legendaris sejak zaman kolonial.
# Out:
# Overwriting lokasi_semarang.csv

# %% [markdown]
# Praktikum 2: Membaca CSV dengan Pandas

# %%
import pandas as pd

NAMA_FILE_CSV = "lokasi_semarang.csv"

def baca_data_lokasi(nama_file: str) -> pd.DataFrame | None:
    """Membaca data lokasi dari file CSV menggunakan Pandas."""
    print(f"Mencoba membaca file CSV: {nama_file}")
    try:
        dataframe = pd.read_csv(nama_file)
        print(" -> File CSV berhasil dibaca.")
        return dataframe
    except FileNotFoundError:
        print(f" -> ERROR: File '{nama_file}' tidak ditemukan!")
        return None
    except pd.errors.EmptyDataError:
        print(f" -> ERROR: File '{nama_file}' kosong.")
        return None
    except Exception as e:
        print(f" -> ERROR saat membaca file CSV: {type(e).__name__} - {e}")
        return None

print("--- Memulai Praktikum 2: Membaca CSV ---")
df_lokasi = baca_data_lokasi(NAMA_FILE_CSV)

if df_lokasi is not None:
    print("\n--- Inspeksi Awal DataFrame ---")
    print("\n1. Lima Baris Pertama (head()):")
    print(df_lokasi.head())

    print("\n2. Informasi DataFrame (info()):")
    df_lokasi.info()

    jumlah_baris, jumlah_kolom = df_lokasi.shape
    print(f"\n3. Dimensi Data:\n Jumlah Lokasi (Baris): {jumlah_baris}\n Jumlah Atribut (Kolom): {jumlah_kolom}")

    print(f"\n4. Nama Kolom:\n {list(df_lokasi.columns)}")
else:
    print("\nTidak dapat melanjutkan inspeksi karena gagal membaca file CSV.")
print("\n--- Praktikum 2 Selesai ---")
# Out:
# --- Memulai Praktikum 2: Membaca CSV ---
# Mencoba membaca file CSV: lokasi_semarang.csv
#  -> File CSV berhasil dibaca.
#
# --- Inspeksi Awal DataFrame ---
#
# 1. Lima Baris Pertama (head()):
#                        Nama  Latitude  Longitude            Tipe  \
# 0               Lawang Sewu   -6.9840   110.4105  Wisata Sejarah
# 1              Simpang Lima   -6.9929   110.4200        Landmark
# 2  Masjid Agung Jawa Tengah   -6.9892   110.4452   Tempat Ibadah
# 3     Klenteng Sam Poo Kong   -6.9980   110.4030   Tempat Ibadah
# 4              Brown Canyon   -7.0375   110.4875     Wisata Alam
#
#                                            Deskripsi
# 0  Bangunan bersejarah peninggalan Belanda dengan...
# 1  Alun-alun pusat kota Semarang, tempat berkumpu...
# 2  Masjid besar dengan arsitektur megah dan menar...
# 3  Klenteng bersejarah peninggalan Laksamana Chen...
# 4  Tebing bekas penambangan galian C yang unik me...
#
# 2. Informasi DataFrame (info()):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nama       10 non-null     object
#  1   Latitude   10 non-null     float64
#  2   Longitude  10 non-null     float64
#  3   Tipe       10 non-null     object
#  4   Deskripsi  10 non-null     object
# dtypes: float64(2), object(3)
# memory usage: 532.0+ bytes
#
# 3. Dimensi Data:
#  Jumlah Lokasi (Baris): 10
#  Jumlah Atribut (Kolom): 5
#
# 4. Nama Kolom:
#  ['Nama', 'Latitude', 'Longitude', 'Tipe', 'Deskripsi']
#
# --- Praktikum 2 Selesai ---

# %% [markdown]
# Praktikum 3: Mendesain Kelas OOP

# %%
from abc import ABC, abstractmethod

# --- PRAKTIKUM 3: Mendesain Kelas OOP ---
class Lokasi(ABC):
    def __init__(self, nama: str, latitude: float, longitude: float):
        self.nama = str(nama) if nama else "Tanpa Nama"
        try:
            self.latitude = float(latitude)
            self.longitude = float(longitude)
        except (ValueError, TypeError, SystemError):
            self.latitude, self.longitude = 0.0, 0.0

    def get_koordinat(self) -> tuple:
        return (self.latitude, self.longitude)

    @abstractmethod
    def get_info_popup(self) -> str:
        pass

    def __repr__(self) -> str:
        return f"{type(self).__name__}(nama='{self.nama}', lat={self.latitude:.4f}, lon={self.longitude:.4f})"

    def __str__(self) -> str:
        return f"{self.nama} [{type(self).__name__}]"

class TempatWisata(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, jenis: str, deskripsi: str):
        super().__init__(nama, latitude, longitude)
        self.jenis_wisata = str(jenis) if jenis else "Umum"
        self.deskripsi = str(deskripsi) if deskripsi else "Tidak ada deskripsi."

    def get_info_popup(self) -> str:
        return f"{self.nama}{self.jenis_wisata}{self.deskripsi}Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class Kuliner(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, menu_andalan: str):
        super().__init__(nama, latitude, longitude)
        self.menu_andalan = str(menu_andalan) if menu_andalan else "Tidak diketahui"

    def get_info_popup(self) -> str:
        return f"{self.nama}KulinerMenu Andalan: {self.menu_andalan}Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class TempatIbadah(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, agama: str = "Umum", deskripsi: str = ""):
        super().__init__(nama, latitude, longitude)
        self.agama = str(agama) if agama else "Umum"
        self.deskripsi = str(deskripsi) if deskripsi else "Tempat Ibadah"

    def get_info_popup(self) -> str:
        return f"{self.nama}Tempat Ibadah ({self.agama}){self.deskripsi}Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

print("--- Praktikum 3 Selesai: Kelas OOP berhasil didefinisikan ---")
# Out:
# --- Praktikum 3 Selesai: Kelas OOP berhasil didefinisikan ---

# %% [markdown]
# Praktikum 4: Membuat Objek dari Data

# %%
import pandas as pd

# --- PRAKTIKUM 4: Membuat Objek dari Data Pandas ---
def buat_objek_lokasi_dari_df(dataframe: pd.DataFrame) -> list:
    list_objek_lokasi = []

    if dataframe is None or dataframe.empty:
        print("DataFrame kosong atau None, tidak ada objek dibuat.")
        return list_objek_lokasi

    print("\nMembuat objek dari DataFrame...")
    for index, row in dataframe.iterrows():
        nama = row.get('Nama', None)
        lat = row.get('Latitude', None)
        lon = row.get('Longitude', None)
        tipe = row.get('Tipe', 'Lainnya')
        deskripsi = row.get('Deskripsi', '')

        if pd.isna(nama) or pd.isna(lat) or pd.isna(lon):
            continue

        objek = None
        try:
            if 'Wisata' in tipe or tipe == 'Landmark':
                objek = TempatWisata(nama, lat, lon, tipe, deskripsi)
            elif tipe == 'Kuliner':
                objek = Kuliner(nama, lat, lon, deskripsi)
            elif 'Ibadah' in tipe:
                agama_info = "Umum"
                if "Islam" in tipe: agama_info = "Islam"
                elif "Kristen" in tipe: agama_info = "Kristen"
                elif "Klenteng" in tipe: agama_info = "Tridharma"
                objek = TempatIbadah(nama, lat, lon, agama_info, deskripsi)

            if objek:
                list_objek_lokasi.append(objek)

        except Exception as e:
            print(f" -> GAGAL membuat objek untuk '{nama}' di baris {index}: {e}")

    print(f"Total {len(list_objek_lokasi)} objek lokasi berhasil dibuat dari {len(dataframe)} baris data.")
    return list_objek_lokasi

# Eksekusi Utama Praktikum 4
print("--- Memulai Praktikum 4: Membuat Objek dari Data Pandas ---")

# Memastikan df_lokasi dari Praktikum 2 sudah ada
try:
    list_semua_lokasi = buat_objek_lokasi_dari_df(df_lokasi)
    print("\n--- Daftar Objek Lokasi yang Berhasil Dibuat ---")
    if list_semua_lokasi:
        for idx, lok in enumerate(list_semua_lokasi):
            print(f" {idx+1}. {repr(lok)}")
    else:
        print("Tidak ada objek lokasi yang dibuat.")
except NameError:
    print("ERROR: Variabel 'df_lokasi' belum didefinisikan. Pastikan Cell Praktikum 2 sudah dijalankan!")

print("\n--- Praktikum 4 Selesai ---")
# Out:
# --- Memulai Praktikum 4: Membuat Objek dari Data Pandas ---
#
# Membuat objek dari DataFrame...
# Total 10 objek lokasi berhasil dibuat dari 10 baris data.
#
# --- Daftar Objek Lokasi yang Berhasil Dibuat ---
#  1. TempatWisata(nama='Lawang Sewu', lat=-6.9840, lon=110.4105)
#  2. TempatWisata(nama='Simpang Lima', lat=-6.9929, lon=110.4200)
#  3. TempatIbadah(nama='Masjid Agung Jawa Tengah', lat=-6.9892, lon=110.4452)
#  4. TempatIbadah(nama='Klenteng Sam Poo Kong', lat=-6.9980, lon=110.4030)
#  5. TempatWisata(nama='Brown Canyon', lat=-7.0375, lon=110.4875)
#  6. Kuliner(nama='Lumpia Gang Lombok', lat=-6.9718, lon=110.4255)
#  7. TempatWisata(nama='Kota Lama', lat=-6.9690, lon=110.4250)
#  8. TempatWisata(nama='Pantai Marina', lat=-6.9585, lon=110.3875)
#  9. TempatWisata(nama='Kampoeng Kopi Banaran', lat=-7.2780, lon=110.4010)
#  10. Kuliner(nama='Toko Oen', lat=-6.9715, lon=110.4235)
#
# --- Praktikum 4 Selesai ---

# %% [markdown]
# Praktikum 5: Visualisasi dengan Folium

# %%
import folium

NAMA_FILE_PETA = "peta_interaktif_semarang.html"

# --- PRAKTIKUM 5: Visualisasi Peta Dasar ---
def buat_peta_lokasi_folium_dasar(list_objek: list, file_output: str = NAMA_FILE_PETA):
    if not list_objek:
        print("Tidak ada objek lokasi untuk dipetakan.")
        return None

    print(f"\nMemulai pembuatan peta Folium dari {len(list_objek)} lokasi...")

    try:
        lat_tengah = list_objek[0].latitude
        lon_tengah = list_objek[0].longitude
    except IndexError:
        lat_tengah, lon_tengah = -6.9929, 110.4200

    peta = folium.Map(location=[lat_tengah, lon_tengah], zoom_start=13, tiles="OpenStreetMap")
    print(f" -> Objek peta dibuat, berpusat di ({lat_tengah:.4f}, {lon_tengah:.4f})")

    jumlah_marker_valid = 0

    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):
            info_popup_html = lok.get_info_popup()
            folium.Marker(
                location=koordinat,
                popup=folium.Popup(info_popup_html, max_width=300),
                tooltip=lok.nama
            ).add_to(peta)
            jumlah_marker_valid += 1
        else:
            print(f" -> Melewati marker untuk '{lok.nama}' karena koordinat tidak valid.")

    try:
        peta.save(file_output)
        print(f"\n-> Peta berhasil dibuat dan disimpan sebagai '{file_output}'.")
        print(f"   Total marker ditambahkan: {jumlah_marker_valid}")
    except Exception as e:
        print(f"\nERROR saat menyimpan peta Folium: {type(e).__name__} - {e}")

    return peta

# Eksekusi Praktikum 5
print("--- Memulai Praktikum 5: Visualisasi Peta dengan Folium ---")
peta_dasar = buat_peta_lokasi_folium_dasar(list_semua_lokasi, NAMA_FILE_PETA)
print(f"\nSilakan buka file {NAMA_FILE_PETA} atau lihat hasil render di bawah ini.")
print("\n--- Praktikum 5 Selesai ---")

# Tampilkan di Colab
peta_dasar
# Out:
# --- Memulai Praktikum 5: Visualisasi Peta dengan Folium ---
#
# Memulai pembuatan peta Folium dari 10 lokasi...
#  -> Objek peta dibuat, berpusat di (-6.9840, 110.4105)
#
# -> Peta berhasil dibuat dan disimpan sebagai 'peta_interaktif_semarang.html'.
#    Total marker ditambahkan: 10
#
# Silakan buka file peta_interaktif_semarang.html atau lihat hasil render di bawah ini.
#
# --- Praktikum 5 Selesai ---
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f60d63623d1e06bf4f3fbdbe922b9b39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f60d63623d1e06bf4f3fbdbe922b9b39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f60d63623d1e06bf4f3fbdbe922b9b39 = L.map(
#                 &quot;map_f60d63623d1e06bf4f3fbdbe922b9b39&quot;,
#                 {
#                     center: [-6.984, 110.4105],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b141f53833da6cebdb580254520aec8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b141f53833da6cebdb580254520aec8.addTo(map_f60d63623d1e06bf4f3fbdbe922b9b39);
#
#
#             var marker_f79079a1d37c334e0c56c0df37b13941 = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_f60d63623d1e06bf4f3fbdbe922b9b39);
#
#
#         var popup_ca670c74339916ad71cd54ef3727274a = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_0a3b17e0f86e21d859bf69e63cb92501 = $(`&lt;div id=&quot;html_0a3b17e0f86e21d859bf69e63cb92501&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lawang SewuWisata SejarahBangunan bersejarah peninggalan Belanda dengan banyak pintu.Koordinat: (-6.9840, 110.4105)&lt;/div&gt;`)[0];
#                 popup_ca670c74339916ad71cd54ef3727274a.setContent(html_0a3b17e0f86e21d859bf69e63cb92501);
#
#
#
#         marker_f79079a1d37c334e0c56c0df37b13941.bindPopup(popup_ca670c74339916ad71cd54ef3727274a)
#         ;
#
#
#
#
#             marker_f79079a1d37c334e0c56c0df37b13941.bindTooltip(
#                 `&lt;div&gt;
#                      Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_3a39756baf5e6a98a54ea05c81f3ff37 = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_f60d63623d1e06bf4f3fbdbe922b9b39);
#
#
#         var popup_a5b6cc3f6e380d8df638f6da089d66f6 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_d02e1417501b214723c5ec4630da2e3c = $(`&lt;div id=&quot;html_d02e1417501b214723c5ec4630da2e3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simpang LimaLandmarkAlun-alun pusat kota Semarang, tempat berkumpul populer.Koordinat: (-6.9929, 110.4200)&lt;/div&gt;`)[0];
#                 popup_a5b6cc3f6e380d8df638f6da089d66f6.setContent(html_d02e1417501b214723c5ec4630da2e3c);
#
#
#
#         marker_3a39756baf5e6a98a54ea05c81f3ff37.bindPopup(popup_a5b6cc3f6e380d8df638f6da089d66f6)
#         ;
#
#
#
#
#             marker_3a39756baf5e6a98a54ea05c81f3ff37.bindTooltip(
#                 `&lt;div&gt;
#                      Simpang Lima
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ace3509b63cac7c02be88d0f8b44b65b = L.marker(
#                 [-6.9892, 110.4452],
#                 {
# }
#             ).addTo(map_f60d63623d1e06bf4f3fbdbe922b9b39);
#
#
#         var popup_e4c0f73dce35500db07d606d77d82de4 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_6f14936d2dccabffd901e05df7bd9e58 = $(`&lt;div id=&quot;html_6f14936d2dccabffd901e05df7bd9e58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Masjid Agung Jawa TengahTempat Ibadah (Umum)Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.Koordinat: (-6.9892, 110.4452)&lt;/div&gt;`)[0];
#                 popup_e4c0f73dce35500db07d606d77d82de4.setContent(html_6f14936d2dccabffd901e05df7bd9e58);
#
#
#
#         marker_ace3509b63cac7c02be88d0f8b44b65b.bindPopup(popup_e4c0f73dce35500db07d606d77d82de4)
#         ;
#
#
#
#
#             marker_ace3509b63cac7c02be88d0f8b44b65b.bindTooltip(
#                 `&lt;div&gt;
#                      Masjid Agung Jawa Tengah
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_bfff665bfed4057e57dc7eea4768cea6 = L.marker(
#                 [-6.998, 110.403],
#                 {
# }
#             ).addTo(map_f60d63623d1e06bf4f3fbdbe922b9b39);
#
#
#         var popup_1fde5d85b819b4f265440731ff22eef7 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_08fd7687a1357cb4ca795c19b1117e8e = $(`&lt;div id=&quot;html_08fd7687a1357cb4ca795c19b1117e8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;K

# %% [markdown]
# Praktikum 6: File Handling Tambahan (Log)

# %%
import folium
import datetime
import os

FILE_LOG = "proses_peta.log"

# --- PRAKTIKUM 6: Fungsi Logging ---
def tulis_log(pesan: str, file_log: str = FILE_LOG):
    """Menulis pesan log ke file dengan timestamp, menggunakan mode append."""
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    try:
        with open(file_log, 'a', encoding='utf-8') as f:
            f.write(f"[{timestamp}] {pesan}\n")
    except IOError as e:
        print(f"ERROR: Gagal menulis ke file log '{file_log}': {e}")

# --- PRAKTIKUM 6: Pembuatan Peta yang Diperbarui (dengan Logging) ---
def buat_peta_lokasi_folium_log(list_objek: list, file_output: str):
    nama_fungsi = "buat_peta_lokasi_folium"

    if not list_objek:
        pesan_log = f"[{nama_fungsi}] Gagal: Tidak ada data lokasi untuk dipetakan."
        print(pesan_log)
        tulis_log(pesan_log)
        return None

    print(f"\n[{nama_fungsi}] Memulai pembuatan peta dari {len(list_objek)} lokasi...")
    tulis_log(f"[{nama_fungsi}] Memulai pembuatan peta '{file_output}' dengan {len(list_objek)} lokasi.")

    try:
        lat_tengah = list_objek[0].latitude
        lon_tengah = list_objek[0].longitude
    except IndexError:
        lat_tengah, lon_tengah = -6.9929, 110.4200

    peta = folium.Map(location=[lat_tengah, lon_tengah], zoom_start=12)

    jumlah_marker = 0
    lokasi_dilewati = []

    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):
            info_popup_html = lok.get_info_popup()
            folium.Marker(
                location=koordinat,
                popup=folium.Popup(info_popup_html, max_width=300),
                tooltip=lok.nama
            ).add_to(peta)
            jumlah_marker += 1
        else:
            lokasi_dilewati.append(lok.nama)

    if lokasi_dilewati:
        pesan_lewat = f"[{nama_fungsi}] Melewati marker untuk: {', '.join(lokasi_dilewati)} (koordinat tidak valid)."
        print(f" -> Peringatan: {pesan_lewat}")
        tulis_log(pesan_lewat)

    try:
        peta.save(file_output)
        pesan_sukses = f"[{nama_fungsi}] Peta '{file_output}' berhasil dibuat dengan {jumlah_marker} marker."
        print(f"-> {pesan_sukses}")
        tulis_log(pesan_sukses)
    except Exception as e:
        pesan_error = f"[{nama_fungsi}] ERROR saat menyimpan peta '{file_output}': {type(e).__name__} - {e}"
        print(f"-> {pesan_error}")
        tulis_log(pesan_error)

    return peta

# Eksekusi Praktikum 6
print("--- Memulai Praktikum 6: File Handling Tambahan (Log) ---")

# (Opsional) Hapus log lama jika ingin mulai bersih saat di-run ulang
if os.path.exists(FILE_LOG):
    os.remove(FILE_LOG)
    print(f"File log lama '{FILE_LOG}' dihapus.")

# Kita buat peta kedua untuk demo logging
print("\nMenjalankan pembuatan peta lagi untuk demo log append...")
peta_dengan_log = buat_peta_lokasi_folium_log(list_semua_lokasi, "peta_kedua.html")

print(f"\nSilakan periksa isi file log '{FILE_LOG}' untuk melihat catatan proses.")

print("\n--- Isi dari proses_peta.log ---")
with open(FILE_LOG, 'r') as f:
    print(f.read())

print("--- Praktikum 6 Selesai ---")

# Tampilkan di Colab
peta_dengan_log
# Out:
# --- Memulai Praktikum 6: File Handling Tambahan (Log) ---
# File log lama 'proses_peta.log' dihapus.
#
# Menjalankan pembuatan peta lagi untuk demo log append...
#
# [buat_peta_lokasi_folium] Memulai pembuatan peta dari 10 lokasi...
# -> [buat_peta_lokasi_folium] Peta 'peta_kedua.html' berhasil dibuat dengan 10 marker.
#
# Silakan periksa isi file log 'proses_peta.log' untuk melihat catatan proses.
#
# --- Isi dari proses_peta.log ---
# [2026-06-25 13:07:35] [buat_peta_lokasi_folium] Memulai pembuatan peta 'peta_kedua.html' dengan 10 lokasi.
# [2026-06-25 13:07:35] [buat_peta_lokasi_folium] Peta 'peta_kedua.html' berhasil dibuat dengan 10 marker.
#
# --- Praktikum 6 Selesai ---
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcbbd6ba16b71717c787e57aaa025854 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcbbd6ba16b71717c787e57aaa025854&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcbbd6ba16b71717c787e57aaa025854 = L.map(
#                 &quot;map_dcbbd6ba16b71717c787e57aaa025854&quot;,
#                 {
#                     center: [-6.984, 110.4105],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8fa9f291d97d96262ac16affd44c394 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c8fa9f291d97d96262ac16affd44c394.addTo(map_dcbbd6ba16b71717c787e57aaa025854);
#
#
#             var marker_5ae4878cb136ace4df8d7cc0a6e06b11 = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_dcbbd6ba16b71717c787e57aaa025854);
#
#
#         var popup_bf23f595b6b06e683c4f4fe9cd47b224 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_9cf702fbdd0af62e2aa5273830c923b8 = $(`&lt;div id=&quot;html_9cf702fbdd0af62e2aa5273830c923b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lawang SewuWisata SejarahBangunan bersejarah peninggalan Belanda dengan banyak pintu.Koordinat: (-6.9840, 110.4105)&lt;/div&gt;`)[0];
#                 popup_bf23f595b6b06e683c4f4fe9cd47b224.setContent(html_9cf702fbdd0af62e2aa5273830c923b8);
#
#
#
#         marker_5ae4878cb136ace4df8d7cc0a6e06b11.bindPopup(popup_bf23f595b6b06e683c4f4fe9cd47b224)
#         ;
#
#
#
#
#             marker_5ae4878cb136ace4df8d7cc0a6e06b11.bindTooltip(
#                 `&lt;div&gt;
#                      Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ebd7a7ddbde73fe71a00b1d6d2a1e762 = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_dcbbd6ba16b71717c787e57aaa025854);
#
#
#         var popup_432a973002b6b04d7eae0d9311bd3892 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_7f2b77e0ff3cdf2f059a529d5abfa70b = $(`&lt;div id=&quot;html_7f2b77e0ff3cdf2f059a529d5abfa70b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Simpang LimaLandmarkAlun-alun pusat kota Semarang, tempat berkumpul populer.Koordinat: (-6.9929, 110.4200)&lt;/div&gt;`)[0];
#                 popup_432a973002b6b04d7eae0d9311bd3892.setContent(html_7f2b77e0ff3cdf2f059a529d5abfa70b);
#
#
#
#         marker_ebd7a7ddbde73fe71a00b1d6d2a1e762.bindPopup(popup_432a973002b6b04d7eae0d9311bd3892)
#         ;
#
#
#
#
#             marker_ebd7a7ddbde73fe71a00b1d6d2a1e762.bindTooltip(
#                 `&lt;div&gt;
#                      Simpang Lima
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_d794b515d63f48202c7ec51f25c7b462 = L.marker(
#                 [-6.9892, 110.4452],
#                 {
# }
#             ).addTo(map_dcbbd6ba16b71717c787e57aaa025854);
#
#
#         var popup_8e7a8fc6f17a7e4852bd8993ce4c38bf = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_07ae1cb3bb516c9efbf50cbba545e9fd = $(`&lt;div id=&quot;html_07ae1cb3bb516c9efbf50cbba545e9fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Masjid Agung Jawa TengahTempat Ibadah (Umum)Masjid besar dengan arsitektur megah dan menara pandang Asmaul Husna.Koordinat: (-6.9892, 110.4452)&lt;/div&gt;`)[0];
#                 popup_8e7a8fc6f17a7e4852bd8993ce4c38bf.setContent(html_07ae1cb3bb516c9efbf50cbba545e9fd);
#
#
#
#         marker_d794b515d63f48202c7ec51f25c7b462.bindPopup(popup_8e7a8fc6f17a7e4852bd8993ce4c38bf)
#         ;
#
#
#
#
#             marker_d794b515d63f48202c7ec51f25c7b462.bindTooltip(
#                 `&lt;div&gt;
#                      Masjid Agung Jawa Tengah
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_9371b8d0b0a4f8caa5982686f221def7 = L.marker(
#                 [-6.998, 110.403],
#                 {
# }
#             ).addTo(map_dcbbd6ba16b71717c787e57aaa025854);
#
#
#         var popup_d894f954ebae7457d7ed95230a585c6d = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_54738052190822717ca63f2558221497 = $(`&lt;div id=&quot;html_54738052190822717ca63f2558221497&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;K

# %% [markdown]
# Penugasan

# %% [markdown]
# Kelas Dasar (Abstrak)

# %%
import pandas as pd
import folium
import datetime
from abc import ABC, abstractmethod

# ==============================================================================
# KELAS DASAR (Abstrak)
# ==============================================================================
class Lokasi(ABC):
    def __init__(self, nama: str, latitude: float, longitude: float):
        self.nama = str(nama) if nama else "Tanpa Nama"
        try:
            self.latitude = float(latitude)
            self.longitude = float(longitude)
        except (ValueError, TypeError):
            self.latitude = 0.0
            self.longitude = 0.0

    def get_koordinat(self) -> tuple:
        return (self.latitude, self.longitude)

    @abstractmethod
    def get_info_popup(self) -> str:
        pass

    def __repr__(self) -> str:
        return f"{type(self).__name__}(nama='{self.nama}', lat={self.latitude:.4f}, lon={self.longitude:.4f})"

    def __str__(self) -> str:
        return f"{self.nama} [{type(self).__name__}]"

# %% [markdown]
# Tambah Data & Kelas (Kelas Turunan OOP)

# %%
# ==============================================================================
# KELAS TURUNAN OOP (Lama & Baru)
# ==============================================================================
class TempatWisata(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, jenis: str, deskripsi: str):
        super().__init__(nama, latitude, longitude)
        self.jenis_wisata = str(jenis) if jenis else "Umum"
        self.deskripsi = str(deskripsi) if deskripsi else "Tidak ada deskripsi"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>{self.jenis_wisata}</i><br><br>{self.deskripsi}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class Kuliner(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, menu_andalan: str):
        super().__init__(nama, latitude, longitude)
        self.menu_andalan = str(menu_andalan) if menu_andalan else "Tidak diketahui"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Kuliner</i><br><br>Menu/Info: {self.menu_andalan}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class TempatIbadah(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, deskripsi: str):
        super().__init__(nama, latitude, longitude)
        self.deskripsi = str(deskripsi) if deskripsi else "Tempat ibadah"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Tempat Ibadah</i><br><br>{self.deskripsi}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class Museum(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, koleksi_utama: str):
        super().__init__(nama, latitude, longitude)
        self.koleksi_utama = str(koleksi_utama) if koleksi_utama else "Koleksi umum"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Museum</i><br><br>Koleksi/Info: {self.koleksi_utama}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class TamanKota(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, fasilitas: str):
        super().__init__(nama, latitude, longitude)
        self.fasilitas = str(fasilitas) if fasilitas else "Fasilitas umum"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Taman Kota</i><br><br>Fasilitas/Info: {self.fasilitas}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

class KantorPemerintahan(Lokasi):
    def __init__(self, nama: str, latitude: float, longitude: float, fungsi: str):
        super().__init__(nama, latitude, longitude)
        self.fungsi = str(fungsi) if fungsi else "Layanan pemerintahan"

    def get_info_popup(self) -> str:
        return f"<h4><b>{self.nama}</b></h4><i>Kantor Pemerintahan</i><br><br>Fungsi/Info: {self.fungsi}<br><br>Koordinat: ({self.latitude:.4f}, {self.longitude:.4f})"

# %% [markdown]
# Fungsi Baca Data CSV

# %%
# ==============================================================================
# FUNGSI BACA CSV & PARSING DATAFRAME KE OBJEK
# ==============================================================================
def baca_data_lokasi(nama_file: str = "lokasi_semarang.csv") -> pd.DataFrame | None:
    try:
        dataframe = pd.read_csv(nama_file)
        print(f"File '{nama_file}' berhasil dibaca.")
        return dataframe
    except Exception as e:
        print(f"ERROR saat membaca file CSV: {e}")
        return None

def buat_objek_lokasi_dari_df(dataframe: pd.DataFrame) -> list:
    list_objek_lokasi = []
    if dataframe is None or dataframe.empty:
        return list_objek_lokasi

    for index, row in dataframe.iterrows():
        nama = row.get("Nama", None)
        lat = row.get("Latitude", None)
        lon = row.get("Longitude", None)
        tipe = row.get("Tipe", "Lainnya")
        deskripsi = row.get("Deskripsi", "")

        if pd.isna(nama) or pd.isna(lat) or pd.isna(lon):
            continue

        objek = None
        try:
            if "Wisata" in tipe or tipe == "Landmark":
                objek = TempatWisata(nama, lat, lon, tipe, deskripsi)
            elif tipe == "Kuliner":
                objek = Kuliner(nama, lat, lon, deskripsi)
            elif tipe == "Tempat Ibadah":
                objek = TempatIbadah(nama, lat, lon, deskripsi)
            elif tipe == "Museum":
                objek = Museum(nama, lat, lon, deskripsi)
            elif tipe == "Taman Kota":
                objek = TamanKota(nama, lat, lon, deskripsi)
            elif tipe == "Kantor Pemerintahan":
                objek = KantorPemerintahan(nama, lat, lon, deskripsi)

            if objek:
                list_objek_lokasi.append(objek)
        except Exception as e:
            print(f"Gagal membuat objek untuk '{nama}': {e}")

    print(f"Total objek lokasi yang berhasil dibuat: {len(list_objek_lokasi)}")
    return list_objek_lokasi

def tulis_log(pesan: str, file_log: str = "proses_peta.log") -> None:
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    try:
        with open(file_log, "a", encoding="utf-8") as f:
            f.write(f"[{timestamp}] {pesan}\n")
    except:
        pass

# %% [markdown]
# Konfigurasi Peta

# %%
# %%writefile config_peta.txt
# -6.9929
# 110.4200
# 14
# Out:
# Overwriting config_peta.txt

# %%
# ==============================================================================
# FUNGSI BACA KONFIGURASI PETA UNTUK TENGAH KOORDINAT
# ==============================================================================
def baca_konfigurasi_peta(nama_file: str = "config_peta.txt") -> tuple:
    default_lat, default_lon, default_zoom = -6.9929, 110.4200, 13
    try:
        with open(nama_file, "r", encoding="utf-8") as f:
            baris = f.readlines()
        lat = float(baris[0].strip())
        lon = float(baris[1].strip())
        zoom = int(baris[2].strip())
        print(f"Konfigurasi peta dibaca dari '{nama_file}'.")
        return lat, lon, zoom
    except:
        return default_lat, default_lon, default_zoom

# %% [markdown]
# Fungsi Desain Marker

# %%
def tentukan_ikon(lok: Lokasi) -> folium.Icon:
    if isinstance(lok, TempatWisata):
        return folium.Icon(color="red", icon="map-marker", prefix="fa") # Diganti merah
    elif isinstance(lok, Kuliner):
        return folium.Icon(color="darkpurple", icon="coffee", prefix="fa") # Ikon cangkir kopi
    elif isinstance(lok, TempatIbadah):
        return folium.Icon(color="blue", icon="heart", prefix="fa") # Warna biru ikon hati
    elif isinstance(lok, Museum):
        return folium.Icon(color="cadetblue", icon="institution", prefix="fa")
    elif isinstance(lok, TamanKota):
        return folium.Icon(color="darkgreen", icon="leaf", prefix="fa") # Warna hijau tua ikon daun
    elif isinstance(lok, KantorPemerintahan):
        return folium.Icon(color="black", icon="building", prefix="fa") # Warna hitam ikon gedung
    else:
        return folium.Icon(color="lightblue", icon="info")

def buat_peta_lokasi_folium(list_objek: list, file_output: str = "peta_interaktif_semarang.html"):
    nama_fungsi = "buat_peta_lokasi_folium"
    if not list_objek:
        return None

    lat_tengah, lon_tengah, zoom_awal = baca_konfigurasi_peta("config_peta.txt")
    peta = folium.Map(location=[lat_tengah, lon_tengah], zoom_start=zoom_awal, tiles="OpenStreetMap")

    jumlah_marker = 0
    for lok in list_objek:
        koordinat = lok.get_koordinat()
        if koordinat != (0.0, 0.0):
            folium.Marker(
                location=koordinat,
                popup=folium.Popup(lok.get_info_popup(), max_width=300),
                tooltip=lok.nama,
                icon=tentukan_ikon(lok)
            ).add_to(peta)
            jumlah_marker += 1

    try:
        peta.save(file_output)
        print(f"[{nama_fungsi}] Peta '{file_output}' berhasil dibuat dengan {jumlah_marker} marker.")

        # KUNCI UTAMA: Wajib mengembalikan objek 'peta' agar notebook bisa merendernya langsung!
        return peta

    except Exception as e:
        print(f"ERROR saat menyimpan peta: {e}")
        return None

# %% [markdown]
# Kode Utama

# %%
# ==============================================================================
# KODE UTAMA (Dibuat rata kiri sepenuhnya agar Colab mau menggambar peta)
# ==============================================================================
NAMA_FILE_CSV = "lokasi_semarang.csv"
NAMA_FILE_PETA = "peta_interaktif_semarang.html"

print("=== MEMULAI PROGRAM UTAMA SIG ===")

df_lokasi = baca_data_lokasi(NAMA_FILE_CSV)
list_semua_lokasi = buat_objek_lokasi_dari_df(df_lokasi)

print(f"Total {len(list_semua_lokasi)} objek berhasil diinstansiasi.")
lat_c, lon_c, zm = baca_konfigurasi_peta()
print(f"Berhasil membaca file konfigurasi: Lat={lat_c}, Lon={lon_c}, Zoom={zm}")

# Panggil fungsi pembuat peta
peta_akhir = buat_peta_lokasi_folium(list_semua_lokasi, NAMA_FILE_PETA)

print("=== PROGRAM SELESAI ===")

# Ditulis rata kiri penuh tanpa spasi di depannya agar langsung dirender otomatis
peta_akhir
# Out:
# === MEMULAI PROGRAM UTAMA SIG ===
# File 'lokasi_semarang.csv' berhasil dibaca.
# Total objek lokasi yang berhasil dibuat: 10
# Total 10 objek berhasil diinstansiasi.
# Konfigurasi peta dibaca dari 'config_peta.txt'.
# Berhasil membaca file konfigurasi: Lat=-6.9929, Lon=110.42, Zoom=14
# Konfigurasi peta dibaca dari 'config_peta.txt'.
# [buat_peta_lokasi_folium] Peta 'peta_interaktif_semarang.html' berhasil dibuat dengan 10 marker.
# === PROGRAM SELESAI ===
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_198987b7f3b7ea22962dbc518bfbfec5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_198987b7f3b7ea22962dbc518bfbfec5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_198987b7f3b7ea22962dbc518bfbfec5 = L.map(
#                 &quot;map_198987b7f3b7ea22962dbc518bfbfec5&quot;,
#                 {
#                     center: [-6.9929, 110.42],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_51810faf9af80b1096b74b667c114f6f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_51810faf9af80b1096b74b667c114f6f.addTo(map_198987b7f3b7ea22962dbc518bfbfec5);
#
#
#             var marker_4f18db131f676ffa6a49c38934bf9968 = L.marker(
#                 [-6.984, 110.4105],
#                 {
# }
#             ).addTo(map_198987b7f3b7ea22962dbc518bfbfec5);
#
#
#             var icon_dd40dbd200151476b7eb5b4e5499cca8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;map-marker&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_e0a87344ec6d27735e187aba1c5aab0b = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_e4abd1c92923f56acc0c361a124c125d = $(`&lt;div id=&quot;html_e4abd1c92923f56acc0c361a124c125d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Lawang Sewu&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Wisata Sejarah&lt;/i&gt;&lt;br&gt;&lt;br&gt;Bangunan bersejarah peninggalan Belanda dengan banyak pintu.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9840, 110.4105)&lt;/div&gt;`)[0];
#                 popup_e0a87344ec6d27735e187aba1c5aab0b.setContent(html_e4abd1c92923f56acc0c361a124c125d);
#
#
#
#         marker_4f18db131f676ffa6a49c38934bf9968.bindPopup(popup_e0a87344ec6d27735e187aba1c5aab0b)
#         ;
#
#
#
#
#             marker_4f18db131f676ffa6a49c38934bf9968.bindTooltip(
#                 `&lt;div&gt;
#                      Lawang Sewu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_4f18db131f676ffa6a49c38934bf9968.setIcon(icon_dd40dbd200151476b7eb5b4e5499cca8);
#
#
#             var marker_0c3a1fd4503047a81b6b70005ab32ad8 = L.marker(
#                 [-6.9929, 110.42],
#                 {
# }
#             ).addTo(map_198987b7f3b7ea22962dbc518bfbfec5);
#
#
#             var icon_55595b6e065d7ceed1d057071263f0f2 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;map-marker&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_260a43265c8d74268af16b871a0070a3 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_577d65f913e462bd319cca6516925d62 = $(`&lt;div id=&quot;html_577d65f913e462bd319cca6516925d62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;h4&gt;&lt;b&gt;Simpang Lima&lt;/b&gt;&lt;/h4&gt;&lt;i&gt;Landmark&lt;/i&gt;&lt;br&gt;&lt;br&gt;Alun-alun pusat kota Semarang, tempat berkumpul populer.&lt;br&gt;&lt;br&gt;Koordinat: (-6.9929, 110.4200)&lt;/div&gt;`)[0];
#                 popup_260a43265c8d74268af16b871a0070a3.setContent(html_577d65f913e462bd319cca6516925d62);
#
#
#
#         marker_0c3a1fd4503047a81b6b70005ab32ad8.bindPopup(popup_260a43265c8d74268af16b871a0070a3)
#         ;
#
#
#
#
#             marker_0c3a1fd4503047a81b6b70005ab32ad8.bindTooltip(
#                 `&lt;div&gt;
#                      Simpang Lima
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_0c3a1fd4503047a81b6b70005ab32ad8.setIcon(icon_55595b6e065d7ceed1d057071263f0f2);
#
#
#             var marker_83df0eba556dc6d3a8cd546423fba498 = L.marker(
#                 [-6.9892, 110.4452],
#                 {
# }
#             ).addTo(map_198987b7f3b7ea22962dbc518bfbfec5);
#
#
#             var icon_48a46d51c2f3f3c80c28cf4c1261c403 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quo
